# %%
import pandas as pd
df = pd.read_csv("/Users/umeshnagar/Downloads/sample_data_bar.csv")
df
# Out:
#     Forecast Type  Products  % of Total for Products
# 0            Pune      1071                17.525773
# 1       Rajasthan       762                12.469318
# 2        Banglore       620                10.145639
# 3        Hydrabad       559                 9.147439
# 4          Mumbai       551                 9.016528
# 5   Utter Pradesh       540                 8.836524
# 6          Panjab       465                 7.609229
# 7          Gujrat       443                 7.249223
# 8        Hariyana       394                 6.447390
# 9           Delhi       327                 5.351006
# 10         Karale       190                 3.109147
# 11        Manipur       189                 3.092784

# %%
def add_bar_percentage(df_ax, x_end_margin = 5, y_end_margin = .1, xlable = 'Category', ylable = 'Values', title = 'Added a title'):
    for p in df_ax.patches:
        percentage = (p.get_width() / total) * 100
        ax.annotate(f'{percentage:.2f}%', (p.get_x() + p.get_width() + x_end_margin, p.get_y() + .1))
    plt.xlabel(xlable)
    plt.ylabel(ylable)
    plt.title(title)

    # Show the plot
    plt.show()

# %%
ax = df.sort_values('Products', ascending = True).plot('Forecast Type', 'Products', kind = 'barh',color = 'g',figsize = (12,7))
add_bar_percentage(ax, x_end_margin = 5, y_end_margin = .1, xlable = 'Category', ylable = 'Values', title = 'Added a title')
